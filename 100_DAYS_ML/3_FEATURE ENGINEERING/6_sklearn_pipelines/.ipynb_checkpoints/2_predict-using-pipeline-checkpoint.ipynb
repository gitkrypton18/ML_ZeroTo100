# %%
import pickle
import numpy as np

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
# Assume user input
test_input2 = np.array([2, 'male', 31.0, 0, 0, 10.5, 'S'],dtype=object).reshape(1,7)

# %%
pipe.predict(test_input2)
# Out:
# F:\ANACONDA\envs\ds\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# F:\ANACONDA\envs\ds\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# File F:\ANACONDA\envs\ds\lib\site-packages\sklearn\pipeline.py:53, in _raise_or_warn_if_not_fitted(estimator)
#      52 try:
# ---> 53     yield
#      54 except NotFittedError as exc:
#
# File F:\ANACONDA\envs\ds\lib\site-packages\sklearn\pipeline.py:789, in Pipeline.predict(self, X, **params)
#     788         Xt = transform.transform(Xt)
# --> 789     return self.steps[-1][1].predict(Xt, **params)
#     791 # metadata routing enabled
#
# File F:\ANACONDA\envs\ds\lib\site-packages\sklearn\tree\_classes.py:529, in BaseDecisionTree.predict(self, X, check_input)
#     507 """Predict class or regression value for X.
#     508
#     509 For a classification model, the predicted class for each sample in X is
#    (...)
#     527     The predicted classes, or the predict values.
#     528 """
# --> 529 check_is_fitted(self)
#     530 X = self._validate_X_predict(X, check_input)
#
# File F:\ANACONDA\envs\ds\lib\site-packages\sklearn\utils\validation.py:1754, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1753 if not _is_fitted(estimator, attributes, all_or_any):
# -> 1754     raise NotFittedError(msg % {"name": type(estimator).__name__})
#
# NotFittedError: This DecisionTreeClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
#
# The above exception was the direct cause of the following exception:
#
# NotFittedError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pipe.predict(test_input2)
#
# File F:\ANACONDA\envs\ds\lib\site-packages\sklearn\pipeline.py:783, in Pipeline.predict(self, X, **params)
#     741 """Transform the data, and apply `predict` with the final estimator.
#     742
#     743 Call `transform` of each transformer in the pipeline. The transformed
#    (...)
#     780     Result of calling `predict` on the final estimator.
#     781 """
#     782 # TODO(1.8): Remove the context manager and use check_is_fitted(self)
# --> 783 with _raise_or_warn_if_not_fitted(self):
#     784     Xt = X
#     786     if not _routing_enabled():
#
# File F:\ANACONDA\envs\ds\lib\contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File F:\ANACONDA\envs\ds\lib\site-packages\sklearn\pipeline.py:55, in _raise_or_warn_if_not_fitted(estimator)
#      53     yield
#      54 except NotFittedError as exc:
# ---> 55     raise NotFittedError("Pipeline is not fitted yet.") from exc
#      57 # we only get here if the above didn't raise
#      58 try:
#
# NotFittedError: Pipeline is not fitted yet.
