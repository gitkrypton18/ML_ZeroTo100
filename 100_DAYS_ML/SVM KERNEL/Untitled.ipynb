# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d
from matplotlib.axes._axes import _log as matplotlib_axes_longer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from matplotlib.colors import ListedColormap

# %%
from sklearn.datasets.samples_generator import makee_circles
X,y = make_circles(100,factor=.1,noise=.1)
plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='bwr')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from sklearn.datasets.samples_generator import makee_circles
#       2 X,y = make_circles(100,factor=.1,noise=.1)
#       3 plt.scatter(X[:,0],X[:,1],c=y,s=50,cmap='bwr')
#
# ModuleNotFoundError: No module named 'sklearn.datasets.samples_generator'
